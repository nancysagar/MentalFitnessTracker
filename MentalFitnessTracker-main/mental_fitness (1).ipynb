# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %%
df1 = pd.read_csv("prevalence-by-mental-and-substance-use-disorder.csv")

# %%
df1.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.228979
# 1                                           0.228120
# 2                                           0.227328
# 3                                           0.226468
# 4                                           0.225567
#
#    Prevalence - Bipolar disorder - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.721207
# 1                                           0.719952
# 2                                           0.718418
# 3                                           0.717452
# 4                                           0.717012
#
#    Prevalence - Eating disorders - Sex: Both - Age: Age-standardized (Percent)  \
# ...

# %%
df2 = pd.read_csv("mental-and-substance-use-as-share-of-disease (1).csv")
df2.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    DALYs (Disability-Adjusted Life Years) - Mental disorders - Sex: Both - Age: All Ages (Percent)
# 0                                           1.696670
# 1                                           1.734281
# 2                                           1.791189
# 3                                           1.776779
# 4                                           1.712986

# %% [markdown]
# ## Merging two datasets

# %%
data = pd.merge(df1, df2)
data.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.228979
# 1                                           0.228120
# 2                                           0.227328
# 3                                           0.226468
# 4                                           0.225567
#
#    Prevalence - Bipolar disorder - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.721207
# 1                                           0.719952
# 2                                           0.718418
# 3                                           0.717452
# 4                                           0.717012
#
#    Prevalence - Eating disorders - Sex: Both - Age: Age-standardized (Percent)  \
# ...

# %% [markdown]
# ### Data Cleaning

# %%
data.isnull().sum()
# Out:
# Entity                                                                                               0
# Code                                                                                               690
# Year                                                                                                 0
# Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)                             0
# Prevalence - Bipolar disorder - Sex: Both - Age: Age-standardized (Percent)                          0
# Prevalence - Eating disorders - Sex: Both - Age: Age-standardized (Percent)                          0
# Prevalence - Anxiety disorders - Sex: Both - Age: Age-standardized (Percent)                         0
# Prevalence - Drug use disorders - Sex: Both - Age: Age-standardized (Percent)                        0
# Prevalence - Depressive disorders - Sex: Both - Age: Age-standardized (Percent)                      0
# ...

# %%
data.drop('Code',axis=1,inplace=True)
data.head()
# Out:
#         Entity  Year  \
# 0  Afghanistan  1990
# 1  Afghanistan  1991
# 2  Afghanistan  1992
# 3  Afghanistan  1993
# 4  Afghanistan  1994
#
#    Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.228979
# 1                                           0.228120
# 2                                           0.227328
# 3                                           0.226468
# 4                                           0.225567
#
#    Prevalence - Bipolar disorder - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.721207
# 1                                           0.719952
# 2                                           0.718418
# 3                                           0.717452
# 4                                           0.717012
#
#    Prevalence - Eating disorders - Sex: Both - Age: Age-standardized (Percent)  \
# ...

# %%
data.size,data.shape
# Out:
# (68400, (6840, 10))

# %%
#data.set_axis(['Country', 'Year', 'Schizophrenia', 'Biopolar_disorder','Eating_disorder', 'Anxiety', 'drug_usage', 'depression', 'alcohol', 'mental_fitness'], axis='columns',inplace=True)
data_with_new_columns = data.copy()  # Create a copy of the DataFrame
data_with_new_columns.set_axis(['Country', 'Year', 'Schizophrenia', 'Biopolar_disorder',
                               'Eating_disorder', 'Anxiety', 'drug_usage', 'depression',
                               'alcohol', 'mental_diorder'], axis='columns')

# Use data_with_new_columns for further operations
# Out:
#           Country  Year  Schizophrenia  Biopolar_disorder  Eating_disorder  \
# 0     Afghanistan  1990       0.228979           0.721207         0.131001
# 1     Afghanistan  1991       0.228120           0.719952         0.126395
# 2     Afghanistan  1992       0.227328           0.718418         0.121832
# 3     Afghanistan  1993       0.226468           0.717452         0.117942
# 4     Afghanistan  1994       0.225567           0.717012         0.114547
# ...           ...   ...            ...                ...              ...
# 6835     Zimbabwe  2015       0.209359           0.560882         0.099610
# 6836     Zimbabwe  2016       0.209979           0.561768         0.100821
# 6837     Zimbabwe  2017       0.210631           0.562612         0.101671
# 6838     Zimbabwe  2018       0.211237           0.563283         0.102398
# 6839     Zimbabwe  2019       0.211969           0.563820         0.102902
#
#        Anxiety  drug_usage  depression   alcohol  mental_diorder
# ...

# %%
data.head()
# Out:
#         Entity  Year  \
# 0  Afghanistan  1990
# 1  Afghanistan  1991
# 2  Afghanistan  1992
# 3  Afghanistan  1993
# 4  Afghanistan  1994
#
#    Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.228979
# 1                                           0.228120
# 2                                           0.227328
# 3                                           0.226468
# 4                                           0.225567
#
#    Prevalence - Bipolar disorder - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.721207
# 1                                           0.719952
# 2                                           0.718418
# 3                                           0.717452
# 4                                           0.717012
#
#    Prevalence - Eating disorders - Sex: Both - Age: Age-standardized (Percent)  \
# ...

# %%
data.to_csv('fitness.csv')

# %% [markdown]
# ## Exploratory Data Analysis

# %%
#plt.figure(figsize=(12,6))
#sns.heatmap(data.corr(),annot=True,cmap='Blues')
#plt.plot()
data_filtered = data.select_dtypes(include=[np.number])
corr_matrix = data_filtered.corr()

# Create the heatmap using the filtered correlation matrix
plt.figure(figsize=(12, 6))
sns.heatmap(corr_matrix, annot=True, cmap='Blues')
plt.show()

# %%
data_with_corrected_names = data.copy()  # Create a copy
data_with_corrected_names.columns = ['Country', 'Year', 'Schizophrenia', 'Biopolar_disorder',
                                     'Eating_disorder', 'Anxiety', 'drug_usage', 'depression',
                                     'alcohol', 'mental_disorder']

sns.jointplot(x='Schizophrenia', y='mental_disorder', data=data_with_corrected_names, kind='reg', color='m')
plt.show()

# %%
# Assuming you've confirmed the correct column name (replace 'Biopolar_disorder' if needed)
data_with_corrected_names = data.copy()  # Create a copy
data_with_corrected_names.columns = ['Country', 'Year', 'Schizophrenia', 'Biopolar_disorder',
                                     'Eating_disorder', 'Anxiety', 'drug_usage', 'depression',
                                     'alcohol', 'mental_fitness']

sns.jointplot(x='Biopolar_disorder', y='mental_fitness', data=data_with_corrected_names, kind='reg', color='blue')
plt.show()

# %%
sns.pairplot(data,corner=True)
plt.show()

# %%
mean = data['DALYs (Disability-Adjusted Life Years) - Mental disorders - Sex: Both - Age: All Ages (Percent)'].mean()
mean
# Out:
# 4.8180618117506135

# %%
mean
# Out:
# 4.8180618117506135

# %%
fig = px.pie(data, values='DALYs (Disability-Adjusted Life Years) - Mental disorders - Sex: Both - Age: All Ages (Percent)', names='Year')

# %%
fig=px.bar(data.head(10),x='Year',y='DALYs (Disability-Adjusted Life Years) - Mental disorders - Sex: Both - Age: All Ages (Percent)',color='Year',template='ggplot2')

# %% [markdown]
# ### Yearwise variations in mental fitness ofvdiff countries

# %%
fig = px.line(data, x="Year", y="DALYs (Disability-Adjusted Life Years) - Mental disorders - Sex: Both - Age: All Ages (Percent)", color='Entity', markers=True, color_discrete_sequence=['red', 'blue'],template='plotly_dark')
#fig.show()

# %%
df = data.copy()

# %%
df.head()
# Out:
#         Entity  Year  \
# 0  Afghanistan  1990
# 1  Afghanistan  1991
# 2  Afghanistan  1992
# 3  Afghanistan  1993
# 4  Afghanistan  1994
#
#    Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.228979
# 1                                           0.228120
# 2                                           0.227328
# 3                                           0.226468
# 4                                           0.225567
#
#    Prevalence - Bipolar disorder - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.721207
# 1                                           0.719952
# 2                                           0.718418
# 3                                           0.717452
# 4                                           0.717012
#
#    Prevalence - Eating disorders - Sex: Both - Age: Age-standardized (Percent)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6840 entries, 0 to 6839
# Data columns (total 10 columns):
#  #   Column                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                           --------------  -----
#  0   Entity                                                                                           6840 non-null   object
#  1   Year                                                                                             6840 non-null   int64
#  2   Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)                         6840 non-null   float64
#  3   Prevalence - Bipolar disorder - Sex: Both - Age: Age-standardized (Percent)                      6840 non-null   float64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
l = LabelEncoder()
for i in df.columns:
    if df[i].dtype == 'object':
        df[i]=l.fit_transform(df[i])

# %%
X = df.drop('DALYs (Disability-Adjusted Life Years) - Mental disorders - Sex: Both - Age: All Ages (Percent)', axis=1)
y = df['DALYs (Disability-Adjusted Life Years) - Mental disorders - Sex: Both - Age: All Ages (Percent)']

from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(X, y, test_size = 0.2, random_state=2)

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
lr = LinearRegression()
lr.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
ytrain_pred = lr.predict(xtrain)
mse = mean_squared_error(ytrain, ytrain_pred)
rmse = (np.sqrt(mean_squared_error(ytrain, ytrain_pred)))
r2 = r2_score(ytrain, ytrain_pred)

# %%
print("The model performance for training set")
print('MSE is {}'.format(mse))
print('MSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")
# Out:
# The model performance for training set
# MSE is 1.389959372405798
# MSE is 1.1789653821914357
# R2 score is 0.7413245790025275

# %%
ytest_pred = lr.predict(xtest)
mse = mean_squared_error(ytest, ytest_pred)
rmse = (np.sqrt(mean_squared_error(ytest, ytest_pred)))
r2 = r2_score(ytest, ytest_pred)

print("The model performance for training set")
print('MSE is {}'.format(mse))
print('MSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")
# Out:
# The model performance for training set
# MSE is 1.1357545319272409
# MSE is 1.0657178481789826
# R2 score is 0.7638974087055268

# %% [markdown]
# ## Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(xtrain, ytrain)
# Out:
# RandomForestRegressor()

# %%
ytraim_pred = rf.predict(xtrain)
mse = mean_squared_error(ytest, ytest_pred)
rmse = (np.sqrt(mean_squared_error(ytest, ytest_pred)))
r2 = r2_score(ytest, ytest_pred)

print("The model performance for training set")
print('MSE is {}'.format(mse))
print('MSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")

ytest_pred = rf.predict(xtest)
mse = mean_squared_error(ytest, ytest_pred)
rmse = (np.sqrt(mean_squared_error(ytest, ytest_pred)))
r2 = r2_score(ytest, ytest_pred)

print("The model performance for test set")
print('MSE is {}'.format(mse))
print('MSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")
# Out:
# The model performance for training set
# MSE is 1.1357545319272409
# MSE is 1.0657178481789826
# R2 score is 0.7638974087055268
#
#
# The model performance for test set
# MSE is 0.029910144464033856
# MSE is 0.17294549564540226
# R2 score is 0.9937822280999686

# %%
from sklearn.preprocessing import LabelEncoder

print("Welcome to Mental Fitness Tracker!\nFill the detail to check your mental fitness!")

# Country should not be included when collecting input data
Country = input('Enter Your country Name:')
Year = int(input("Enter the Year:"))
Schizophrenia = float(input("Enter your Schizophrenia rate in %:"))
Biopolar_disorder = float(input("Enter your Bipolar disorder rate in %:"))
Eating_disorder = float(input("Enter your Eating disorder rate in %:"))
Anxiety = float(input("Enter your Anxiety rate in %:"))
drug_usage = float(input("Enter your Drug Usage rate in per year %:"))
depression = float(input("Enter your Depression rate in %:"))
alcohol = float(input("Enter your Alcohol Consuming rate per year in %:"))

# Convert Country to numerical representation using LabelEncoder
l = LabelEncoder()
Country_encoded = l.fit_transform([Country])

# Concatenate all input variables into a single array for prediction
prediction = rf.predict([[Country_encoded[0], Year, Schizophrenia, Biopolar_disorder, Eating_disorder, Anxiety, drug_usage, depression, alcohol]])
print("\n---------------------------------------------------------------------")
print("Your Mental Fitness is {}%".format(prediction[0] * 10))
# Out:
# Welcome to Mental Fitness Tracker!
# Fill the detail to check your mental fitness!
#
# ---------------------------------------------------------------------
# Your Mental Fitness is 68.62741265792113%

# %%
import joblib

# %%
filename = 'model.sav'

# %%
from joblib import dump

dump(rf, filename)
# Out:
# ['model.sav']

# %%
from joblib import load

load_model = load(filename)

# %%
model_score_r1 = load_model.score(xtest, ytest)

# %%
model_score_r1
# Out:
# 0.9937822280999686
